# %%
import torch

# import vision transformer

from vit_pytorch.vivit import ViT
from vit_pytorch.extractor import Extractor


v = ViT(
    image_size = 128,          # image size
    frames = 16,               # number of frames
    image_patch_size = 16,     # image patch size
    frame_patch_size = 2,      # frame patch size
    num_classes = 1000,
    dim = 1024,
    spatial_depth = 6,         # depth of the spatial transformer
    temporal_depth = 6,        # depth of the temporal transformer
    heads = 8,
    mlp_dim = 2048
)

vit = Extractor(v, return_embeddings_only = True, detach = False, layer=v.to_latent)

# extractor will enable it so the vision transformer returns its embeddings

# import CoCa and instantiate it

from coca_pytorch.coca_pytorch import CoCa

coca = CoCa(
    dim = 512,                     # model dimension
    img_encoder = vit,             # vision transformer - image encoder, returning image embeddings as (batch, seq, dim)
    image_dim = 1024,              # image embedding dimension, if not the same as model dimensions
    num_tokens = 20000,            # number of text tokens
    unimodal_depth = 6,            # depth of the unimodal transformer
    multimodal_depth = 6,          # depth of the multimodal transformer
    dim_head = 64,                 # dimension per attention head
    heads = 8,                     # number of attention heads
    caption_loss_weight = 1.,      # weight on the autoregressive caption loss
    contrastive_loss_weight = 1.,  # weight on the contrastive loss between image and text CLS embeddings
).cpu()

# mock text and images

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('bert-base-cased')


text = tokenizer(
    ["A dog flew over the fence.", "It broke it's femur."],
    padding=True,
    truncation=True,
    return_tensors="pt")

text = text["input_ids"]

images = torch.randn(2, 3, 16, 224, 224).cpu()

# train by giving CoCa your text and images with `return_loss = True`

loss = coca(
    text = text,
    images = images,
    return_loss = True  # set this to True to get the full caption + contrastive loss
)

loss.backward()

# do the above for as much text and images...
# then you can get the caption logits as so

logits = coca(
    text = text,
    images = images
) # (4, 512, 20000)

# and the CLIP-like text and image embeddings as

text_embeds, image_embeds = coca(
    text = text,
    images = images,
    return_embeddings = True
) # (4, 512), (4, 512)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [2], in <cell line: 62>()
#      58 images = torch.randn(2, 3, 16, 224, 224).cpu()
#      60 # train by giving CoCa your text and images with `return_loss = True`
# ---> 62 loss = coca(
#      63     text = text,
#      64     images = images,
#      65     return_loss = True  # set this to True to get the full caption + contrastive loss
#      66 )
#      68 loss.backward()
#      70 # do the above for as much text and images...
#      71 # then you can get the caption logits as so
#
# File ~/opt/anaconda3/envs/SignLanguageInterpreter/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/SignLanguageInterpreter/lib/python3.10/site-packages/coca_pytorch/coca_pytorch.py:415, in CoCa.forward(self, text, images, image_tokens, labels, return_loss, return_embeddings)
#     411     text, labels = text[:, :-1], text[:, 1:]
#     413 text_embeds, text_tokens = self.embed_text(text)
# --> 415 image_embeds, image_tokens = self.embed_image(images=images, image_tokens=image_tokens)
#     417 # return embeddings if that is what the researcher wants
#     419 if return_embeddings:
#
# File ~/opt/anaconda3/envs/SignLanguageInterpreter/lib/python3.10/site-packages/coca_pytorch/coca_pytorch.py:389, in CoCa.embed_image(self, images, image_tokens)
#     387 if exists(images):
#     388     assert exists(self.img_encoder), 'img_encoder must be passed in for automatic image encoding'
# --> 389     image_tokens = self.img_encoder(images)
#     391 # attention pool image tokens
#     393 img_queries = repeat(self.img_queries, 'n d -> b n d', b=image_tokens.shape[0])
#
# File ~/opt/anaconda3/envs/SignLanguageInterpreter/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/SignLanguageInterpreter/lib/python3.10/site-packages/vit_pytorch/extractor.py:82, in Extractor.forward(self, img, return_embeddings_only)
#      79 if not self.hook_registered:
#      80     self._register_hook()
# ---> 82 pred = self.vit(img)
#      84 target_device = self.device if exists(self.device) else img.device
#      85 latents = apply_tuple_or_single(lambda t: t.to(target_device), self.latents)
#
# File ~/opt/anaconda3/envs/SignLanguageInterpreter/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/SignLanguageInterpreter/lib/python3.10/site-packages/vit_pytorch/vivit.py:147, in ViT.forward(self, video)
#     144 x = self.to_patch_embedding(video)
#     145 b, f, n, _ = x.shape
# --> 147 x = x + self.pos_embedding
#     149 if exists(self.spatial_cls_token):
#     150     spatial_cls_tokens = repeat(self.spatial_cls_token, '1 1 d -> b f 1 d', b = b, f = f)
#
# RuntimeError: The size of tensor a (196) must match the size of tensor b (64) at non-singleton dimension 2

# %% [markdown]
# # import torch
#
# # import vision transformer
# from vit_pytorch.extractor import Extractor
#
# import torch
# from vit_pytorch.vivit import ViT
#
# v = ViT(
#     image_size = 128,          # image size
#     frames = 16,               # number of frames
#     image_patch_size = 16,     # image patch size
#     frame_patch_size = 2,      # frame patch size
#     num_classes = 1000,
#     dim = 1024,
#     spatial_depth = 6,         # depth of the spatial transformer
#     temporal_depth = 6,        # depth of the temporal transformer
#     heads = 8,
#     mlp_dim = 2048
# )
#
#
# vit = Extractor(vit, return_embeddings_only = True, detach = False, layer="fc4")
#
# # extractor will enable it so the vision transformer returns its embeddings
#
# # import CoCa and instantiate it
#
# from coca_pytorch.coca_pytorch import CoCa
#
# coca = CoCa(
#     dim = 512,                     # model dimension
#     img_encoder = vit,             # vision transformer - image encoder, returning image embeddings as (batch, seq, dim)
#     image_dim = 1024,              # image embedding dimension, if not the same as model dimensions
#     num_tokens = 20000,            # number of text tokens
#     unimodal_depth = 2,            # depth of the unimodal transformer
#     multimodal_depth = 2,          # depth of the multimodal transformer
#     dim_head = 64,                 # dimension per attention head
#     heads = 8,                     # number of attention heads
#     caption_loss_weight = 1.,      # weight on the autoregressive caption loss
#     contrastive_loss_weight = 1.,  # weight on the contrastive loss between image and text CLS embeddings
# ).cpu()
#
# # mock text and images
#
# from transformers import AutoTokenizer
#
# tokenizer = AutoTokenizer.from_pretrained('bert-base-cased')
#
# #Tokenize the text?
# text = tokenizer(
#     ["A dog flew over the fence.", "It broke it's femur."],
#     padding=True,
#     truncation=True,
#     return_tensors="pt")
#
# for key, value in text.items():
#     print(f"{key}: {value.numpy().tolist()}")
#
# text = text['input_ids']
#
# images = torch.randn(2, 3, 8, 224, 224).cpu()
#
# # train by giving CoCa your text and images with `return_loss = True`
#
# loss = coca(
#     text = text,
#     images = images,
#     return_loss = True  # set this to True to get the full caption + contrastive loss
# )
#
# loss.backward()
#
# # do the above for as much text and images...
# # then you can get the caption logits as so
#
# logits = coca(
#     text = text,
#     images = images
# ) # (4, 512, 20000)
#
# # and the CLIP-like text and image embeddings as
#
# text_embeds, image_embeds = coca(
#     text = text,
#     images = images,
#     return_embeddings = True
# ) # (4, 512), (4, 512)
